# %%
def df_w(W):
    w1, w2 = W[0],w[1]
    df_w1 = 2 * 0.1 * w1
    df_w2 = 2 * 2 * w2
    
    return
# Out:
#  epoch 1:
# STEP 1 - Gradien tai W =[-5.0, -2.0]
# dw1 = -1.0000
# dw1 = -8.0000
#
#  STEP2 - Cap nhat Weights:
# w1_new = -5.0 - 0.1 * -1.0000 = -4.9000
# w2_new = -2.0 - 0.1 * -8.0000 = -1.2000
#
#  epoch 2:
# STEP 1 - Gradien tai W =[-4.9, -1.2]
# dw1 = -0.9800
# dw1 = -4.8000
#
#  STEP2 - Cap nhat Weights:
# w1_new = -4.9 - 0.1 * -0.9800 = -4.8020
# w2_new = -1.2 - 0.1 * -4.8000 = -0.7200
#
#  epoch 3:
# STEP 1 - Gradien tai W =[-4.8020000000000005, -0.72]
# dw1 = -0.9604
# dw1 = -2.8800
#
#  STEP2 - Cap nhat Weights:
# w1_new = -4.8020000000000005 - 0.1 * -0.9604 = -4.7060
# w2_new = -0.72 - 0.1 * -2.8800 = -0.4320
#
#  epoch 4:
# STEP 1 - Gradien tai W =[-4.70596, -0.432]
# dw1 = -0.9412
# dw1 = -1.7280
#
#  STEP2 - Cap nhat Weights:
# w1_new = -4.70596 - 0.1 * -0.9412 = -4.6118
# w2_new = -0.432 - 0.1 * -1.7280 = -0.2592
#
#  epoch 5:
# STEP 1 - Gradien tai W =[-4.6118408, -0.2592]
# dw1 = -0.9224
# dw1 = -1.0368
#
#  STEP2 - Cap nhat Weights:
# ...

# %%
def sgd_momentum(W, dw, V, lr = 0.1, beta = 0.9):
    
    V_new = beta * V + ( 1 - beta ) * dw 
    w = w - lr *    lr * V_new
