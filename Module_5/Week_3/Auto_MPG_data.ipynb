# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Set random seed for reproducibility
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# Define device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load dataset
dataset_path = r"C:\Users\HOME\OneDrive\Documents\Downloads\Auto_MPG_data.csv"
dataset = pd.read_csv(dataset_path)

# Preprocess data
X = dataset.drop(columns='MPG').values
y = dataset['MPG'].values
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=val_size, random_state=random_state, shuffle=is_shuffle
)
X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train, test_size=test_size, random_state=random_state, shuffle=is_shuffle
)

# Normalize data
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)
X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Build Dataset and DataLoader
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
# Define the MLP Model
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        out = self.output(x)
        return out.squeeze(1)

input_dims = X_train.shape[1]
hidden_dims = 64
output_dims = 1
model = MLP(input_dims, hidden_dims, output_dims).to(device)

# %%
# Define loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2)

# %%
# Define R2 score function
def r_squared(y_true, y_pred):
    y_true = torch.Tensor(y_true).to(device)
    y_pred = torch.Tensor(y_pred).to(device)
    mean_true = torch.mean(y_true)
    ss_tot = torch.sum((y_true - mean_true) ** 2)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

# %%
# Train the model
epochs = 100
train_losses, val_losses, train_r2, val_r2 = [], [], [], []

for epoch in range(epochs):
    model.train()
    train_loss, train_target, train_predict = 0.0, [], []
    for X_samples, y_samples in train_loader:
        X_samples, y_samples = X_samples.to(device), y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_predict += outputs.tolist()
        train_target += y_samples.tolist()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_target, train_predict))
    
    model.eval()
    val_loss, val_target, val_predict = 0.0, [], []
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples, y_samples = X_samples.to(device), y_samples.to(device)
            outputs = model(X_samples)
            val_loss += criterion(outputs, y_samples).item()
            val_predict += outputs.tolist()
            val_target += y_samples.tolist()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_target, val_predict))

    print(f'Epoch {epoch+1}/{epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}')
# Out:
# Epoch 1/100 | Train Loss: 282.7696 | Val Loss: 88.6699
# Epoch 2/100 | Train Loss: 137.6303 | Val Loss: 72.2912
# Epoch 3/100 | Train Loss: 71.2735 | Val Loss: 19.7733
# Epoch 4/100 | Train Loss: 24.1454 | Val Loss: 161.7169
# Epoch 5/100 | Train Loss: 92.8138 | Val Loss: 21.3591
# Epoch 6/100 | Train Loss: 17.4018 | Val Loss: 13.7650
# Epoch 7/100 | Train Loss: 20.4737 | Val Loss: 12.0070
# Epoch 8/100 | Train Loss: 37.7618 | Val Loss: 43.9195
# Epoch 9/100 | Train Loss: 17.9690 | Val Loss: 39.0093
# Epoch 10/100 | Train Loss: 23.7735 | Val Loss: 46.1633
# Epoch 11/100 | Train Loss: 30.4893 | Val Loss: 20.4989
# Epoch 12/100 | Train Loss: 9.9094 | Val Loss: 5.8080
# Epoch 13/100 | Train Loss: 15.8280 | Val Loss: 14.4286
# Epoch 14/100 | Train Loss: 12.0749 | Val Loss: 13.2556
# Epoch 15/100 | Train Loss: 14.7775 | Val Loss: 8.1995
# Epoch 16/100 | Train Loss: 10.7564 | Val Loss: 20.1989
# Epoch 17/100 | Train Loss: 12.3653 | Val Loss: 14.8891
# Epoch 18/100 | Train Loss: 15.5615 | Val Loss: 11.8103
# Epoch 19/100 | Train Loss: 13.8779 | Val Loss: 5.1994
# Epoch 20/100 | Train Loss: 7.2584 | Val Loss: 5.0909
# Epoch 21/100 | Train Loss: 8.4593 | Val Loss: 4.8616
# Epoch 22/100 | Train Loss: 6.4056 | Val Loss: 5.1059
# Epoch 23/100 | Train Loss: 10.0837 | Val Loss: 51.4605
# Epoch 24/100 | Train Loss: 10.8463 | Val Loss: 16.6898
# Epoch 25/100 | Train Loss: 9.3684 | Val Loss: 9.1571
# Epoch 26/100 | Train Loss: 10.4627 | Val Loss: 7.2697
# Epoch 27/100 | Train Loss: 6.2744 | Val Loss: 6.3750
# Epoch 28/100 | Train Loss: 10.1971 | Val Loss: 5.1727
# Epoch 29/100 | Train Loss: 6.3354 | Val Loss: 11.2336
# Epoch 30/100 | Train Loss: 17.5983 | Val Loss: 4.6108
# Epoch 31/100 | Train Loss: 7.9109 | Val Loss: 5.8334
# Epoch 32/100 | Train Loss: 6.5690 | Val Loss: 5.8522
# Epoch 33/100 | Train Loss: 6.9809 | Val Loss: 4.6039
# Epoch 34/100 | Train Loss: 7.1685 | Val Loss: 6.3071
# Epoch 35/100 | Train Loss: 7.5529 | Val Loss: 6.1408
# Epoch 36/100 | Train Loss: 5.7359 | Val Loss: 5.9332
# Epoch 37/100 | Train Loss: 5.9781 | Val Loss: 6.2906
# Epoch 38/100 | Train Loss: 7.0314 | Val Loss: 10.1196
# Epoch 39/100 | Train Loss: 7.3560 | Val Loss: 14.8458
# Epoch 40/100 | Train Loss: 7.3216 | Val Loss: 5.7156
# Epoch 41/100 | Train Loss: 5.7522 | Val Loss: 19.9140
# Epoch 42/100 | Train Loss: 7.6933 | Val Loss: 5.5598
# Epoch 43/100 | Train Loss: 7.4258 | Val Loss: 32.5285
# Epoch 44/100 | Train Loss: 10.1848 | Val Loss: 10.7787
# Epoch 45/100 | Train Loss: 6.4546 | Val Loss: 5.0271
# Epoch 46/100 | Train Loss: 7.9935 | Val Loss: 7.3279
# Epoch 47/100 | Train Loss: 6.2374 | Val Loss: 7.1061
# Epoch 48/100 | Train Loss: 5.2600 | Val Loss: 6.6924
# Epoch 49/100 | Train Loss: 6.4943 | Val Loss: 9.1358
# Epoch 50/100 | Train Loss: 6.2244 | Val Loss: 12.1224
# Epoch 51/100 | Train Loss: 7.7783 | Val Loss: 8.0915
# Epoch 52/100 | Train Loss: 10.5197 | Val Loss: 5.2983
# Epoch 53/100 | Train Loss: 7.2807 | Val Loss: 5.1175
# Epoch 54/100 | Train Loss: 6.3517 | Val Loss: 5.3895
# Epoch 55/100 | Train Loss: 5.3879 | Val Loss: 5.1862
# Epoch 56/100 | Train Loss: 5.3808 | Val Loss: 6.4984
# Epoch 57/100 | Train Loss: 7.4620 | Val Loss: 7.0846
# Epoch 58/100 | Train Loss: 6.8112 | Val Loss: 22.8824
# Epoch 59/100 | Train Loss: 8.0487 | Val Loss: 7.0507
# Epoch 60/100 | Train Loss: 5.5469 | Val Loss: 4.7318
# Epoch 61/100 | Train Loss: 5.3811 | Val Loss: 8.6584
# Epoch 62/100 | Train Loss: 10.5819 | Val Loss: 4.8583
# Epoch 63/100 | Train Loss: 6.4560 | Val Loss: 14.0625
# Epoch 64/100 | Train Loss: 6.2566 | Val Loss: 6.1521
# Epoch 65/100 | Train Loss: 8.6945 | Val Loss: 5.0865
# Epoch 66/100 | Train Loss: 5.3286 | Val Loss: 5.3004
# Epoch 67/100 | Train Loss: 5.8653 | Val Loss: 6.3295
# Epoch 68/100 | Train Loss: 10.2646 | Val Loss: 7.4083
# Epoch 69/100 | Train Loss: 6.8360 | Val Loss: 8.9106
# Epoch 70/100 | Train Loss: 6.0830 | Val Loss: 5.4018
# Epoch 71/100 | Train Loss: 5.2067 | Val Loss: 4.9036
# Epoch 72/100 | Train Loss: 5.9496 | Val Loss: 9.1324
# Epoch 73/100 | Train Loss: 6.4426 | Val Loss: 9.7891
# Epoch 74/100 | Train Loss: 6.0808 | Val Loss: 5.4777
# Epoch 75/100 | Train Loss: 5.5852 | Val Loss: 17.6214
# Epoch 76/100 | Train Loss: 7.5610 | Val Loss: 20.5533
# Epoch 77/100 | Train Loss: 11.3496 | Val Loss: 7.3970
# Epoch 78/100 | Train Loss: 6.7060 | Val Loss: 5.6069
# Epoch 79/100 | Train Loss: 5.9906 | Val Loss: 13.9966
# Epoch 80/100 | Train Loss: 8.4567 | Val Loss: 5.9289
# Epoch 81/100 | Train Loss: 10.9950 | Val Loss: 6.4913
# Epoch 82/100 | Train Loss: 6.0110 | Val Loss: 6.2635
# Epoch 83/100 | Train Loss: 5.3822 | Val Loss: 8.6081
# Epoch 84/100 | Train Loss: 5.1791 | Val Loss: 5.2220
# Epoch 85/100 | Train Loss: 4.8853 | Val Loss: 6.8631
# Epoch 86/100 | Train Loss: 4.6783 | Val Loss: 6.3700
# Epoch 87/100 | Train Loss: 4.9880 | Val Loss: 7.6452
# Epoch 88/100 | Train Loss: 5.1174 | Val Loss: 5.3967
# Epoch 89/100 | Train Loss: 5.1308 | Val Loss: 5.4300
# Epoch 90/100 | Train Loss: 6.6458 | Val Loss: 6.1162
# Epoch 91/100 | Train Loss: 5.3241 | Val Loss: 8.1347
# Epoch 92/100 | Train Loss: 7.0896 | Val Loss: 5.7761
# Epoch 93/100 | Train Loss: 6.1322 | Val Loss: 5.5392
# Epoch 94/100 | Train Loss: 9.4440 | Val Loss: 7.8667
# Epoch 95/100 | Train Loss: 6.4156 | Val Loss: 6.1663
# Epoch 96/100 | Train Loss: 8.2800 | Val Loss: 22.2553
# Epoch 97/100 | Train Loss: 7.2965 | Val Loss: 11.1130
# Epoch 98/100 | Train Loss: 7.0437 | Val Loss: 8.1030
# Epoch 99/100 | Train Loss: 6.4266 | Val Loss: 5.4025
# Epoch 100/100 | Train Loss: 6.0006 | Val Loss: 5.0900

# %%
# Evaluate the model on test data

model.eval()
with torch.no_grad():
    y_hat = model(X_test.to(device))
    test_r2 = r_squared(y_test, y_hat) 
    print(f'Test R2 Score: {test_r2}')
# Out:
# Test R2 Score: 0.8778729438781738
